# %% [markdown]
# # **Problem Statement**
#
# ## A global retail company is facing several supply chain challenges, including delayed deliveries, inefficient shipping operations, fluctuating product demand, and inconsistent profitability across different markets. The management team lacks a centralized analytics solution to monitor the end-to-end supply chain process and make informed business decisions.
#
# ## As a Data Analyst, the objective of this project is to analyze the company's supply chain data to identify operational inefficiencies, uncover sales and logistics trends, evaluate customer and product performance, and provide actionable insights that improve overall business performance.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
u=files.upload()
# Out:
#      <input type="file" id="files-f6a469ce-ab86-4859-8162-810bf75dd049" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6a469ce-ab86-4859-8162-810bf75dd049">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(r'/content/DataCoSupplyChainDataset.csv',encoding='latin1')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df1=df.copy()

# %%
df1.shape
# Out:
# (180519, 53)

# %%
df1.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df1['Order Zipcode'].value_counts()
# Out:
# Order Zipcode
# 10035.0    648
# 10009.0    550
# 10024.0    541
# 94122.0    526
# 10011.0    463
#           ...
# 92236.0      1
# 98002.0      1
# 60477.0      1
# 42071.0      1
# 32174.0      1
# Name: count, Length: 609, dtype: int64

# %%
df1.drop(columns=['Product Description'],axis=1,inplace=True)

# %% [markdown]
# The Product Description column contained 100% missing values, making it unsuitable for analysis or feature engineering. Since the column provided no usable information and could not be meaningfully imputed, it was removed from the dataset to reduce unnecessary storage and improve data quality.

# %%
df1.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df1.drop(columns=['Order Zipcode'],axis=1,inplace=True)

# %% [markdown]
# The Order Zipcode column contained approximately 86% missing values. Since the dataset already includes City, State, Country, Region, Latitude, and Longitude, the ZIP code was considered redundant and removed.

# %%
df1.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 3
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
df1['Customer Lname'].value_counts()
# Out:
# Customer Lname
# Smith          64104
# Johnson          989
# Brown            909
# Williams         869
# Jones            859
#                ...
# Atom               1
# Gerginokish        1
# Willi              1
# Mirkckociv         1
# Mclaughli          1
# Name: count, Length: 1109, dtype: int64

# %%
df1['Customer Lname']=df1['Customer Lname'].fillna('Unknown')

# %% [markdown]
# Customer name with null values are filled with unknown keyword.Since it possess only less number of null values.

# %%
df1['Customer Zipcode'].value_counts()
# Out:
# Customer Zipcode
# 725.0      66770
# 921.0        337
# 23455.0      334
# 957.0        297
# 79109.0      292
#            ...
# 60636.0       18
# 89015.0       16
# 32210.0       15
# 7728.0        13
# 11225.0        9
# Name: count, Length: 995, dtype: int64

# %% [markdown]
# The Customer Zipcode column contained 3 missing values (approximately 0.002% of the dataset). Since ZIP codes are identifier fields rather than numerical measures, and the missing percentage is negligible, the null values were retained. This has no significant impact on the overall analysis.

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicates available.

# %%
df1.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df1['shipping date (DateOrders)']=pd.to_datetime(df1['shipping date (DateOrders)'])

# %%
df1['order date (DateOrders)']=pd.to_datetime(df1['order date (DateOrders)'])

# %% [markdown]
# Converting datatype of order date and shipping date to datetime which is in object dtype.

# %%
df1['Customer Zipcode']=df1['Customer Zipcode'].astype('Int64')

# %%
df1['Sales'].value_counts()
# Out:
# Sales
# 129.990005    22372
# 399.980011    17325
# 199.990005    15622
# 299.980011    13729
# 179.970001     5016
#               ...
# 999.989990       10
# 379.959992       10
# 99.000000         9
# 198.000000        9
# 396.000000        9
# Name: count, Length: 193, dtype: int64

# %%
df1['Order Item Discount'].value_counts()
# Out:
# Order Item Discount
# 0.000000      10028
# 6.000000       4589
# 12.000000      4067
# 4.000000       3647
# 8.000000       3626
#               ...
# 50.490002         1
# 85.489998         1
# 140.000000        1
# 33.660000         1
# 61.189999         1
# Name: count, Length: 1017, dtype: int64

# %%
df1['Order Item Product Price'].value_counts()
# Out:
# Order Item Product Price
# 59.990002      24820
# 129.990005     22372
# 50.000000      21035
# 49.980000      19298
# 399.980011     17325
#                ...
# 349.989990        40
# 329.989990        27
# 599.989990        21
# 1999.989990       15
# 999.989990        10
# Name: count, Length: 75, dtype: int64

# %%
money_cols = [
    'Benefit per order',
    'Sales per customer',
    'Order Item Discount',
    'Order Item Product Price',
    'Sales',
    'Order Item Total',
    'Order Profit Per Order',
    'Product Price'
]

df1[money_cols] = df1[money_cols].round(2)

# %% [markdown]
# Several monetary columns contained floating-point precision values (e.g., 129.990005) due to the way floating-point numbers are stored in computer systems. Since financial values are typically represented with two decimal places, these columns were rounded to improve readability, reporting consistency, and data presentation without affecting the underlying business calculations.

# %%
df1['Benefit per order'].value_counts()
# Out:
# Benefit per order
#  0.00      1177
#  143.99     199
#  72.00      194
#  46.80      188
#  24.00      181
#            ...
# -212.41       1
# -18.96        1
#  177.17       1
#  130.98       1
# -196.18       1
# Name: count, Length: 21998, dtype: int64

# %%
df1['Customer FullName']=(df1['Customer Fname'].str.strip()+ ' ' + df1['Customer Lname'].fillna('').str.strip()).str.strip()

# %%
df1.drop(columns=['Customer Fname','Customer Lname'],axis=1,inplace=True)

# %% [markdown]
# The dataset stored customer names in separate First Name and Last Name columns. For improved readability and to simplify customer-level analysis, these columns were combined into a single Customer Full Name field. After verifying the new column, the original name columns were removed to eliminate redundancy.

# %%
df['Product Status'].value_counts(dropna=False)
# Out:
# Product Status
# 0    180519
# Name: count, dtype: int64

# %%
df1.drop(columns=['Product Status'],axis=1,inplace=True)

# %% [markdown]
# The Product Status column was removed because it contained only a single constant value (0) across all records. Since the column exhibited no variability, it did not contribute any meaningful information for analysis or predictive insights.

# %%
df1.drop(columns=['Product Image'],axis=1,inplace=True)

# %% [markdown]
# The dataset doesnt need an image column which consists of images of the products.

# %%
(df1['Customer Id'] == df1['Order Customer Id']).all()
# Out:
# np.True_

# %%
(df['Category Id'] == df['Product Category Id']).all()
# Out:
# np.True_

# %%
(df['Product Card Id'] == df['Order Item Cardprod Id']).all()
# Out:
# np.True_

# %%
df1.drop(columns=[
    'Order Customer Id',
    'Product Category Id',
    'Order Item Cardprod Id'
], inplace=True)

# %% [markdown]
# During data validation, duplicate identifier columns were identified. The values in Order Customer Id, Product Category Id, and Order Item Cardprod Id were found to be identical to Customer Id, Category Id, and Product Card Id, respectively. Since these columns contained redundant information, they were removed to reduce data redundancy and simplify the dataset without affecting analytical integrity.

# %%
df1.drop(columns=['Customer Email','Customer Password'],axis=1, inplace=True)

# %% [markdown]
# Customer Email:
# The Customer Email column was removed as it contains personally identifiable information (PII) that is not required for business analysis.
# Customer Password:
# The Customer Password column was removed because it contains sensitive authentication information that has no analytical value and should not be included in analytics datasets.

# %%
df1['Delivery Status'].value_counts()
# Out:
# Delivery Status
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: count, dtype: int64

# %%
df1['Delivery Status']=df1['Delivery Status'].str.strip().str.lower().str.title()

# %%
df1['Delivery Status'].value_counts()
# Out:
# Delivery Status
# Late Delivery        98977
# Advance Shipping     41592
# Shipping On Time     32196
# Shipping Canceled     7754
# Name: count, dtype: int64

# %%
df1['Order Status'].value_counts()
# Out:
# Order Status
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: count, dtype: int64

# %%
df1['Order Status']=df1['Order Status'].str.strip().str.lower().str.title()

# %%
df1['Order Status'].value_counts()
# Out:
# Order Status
# Complete           59491
# Pending_Payment    39832
# Processing         21902
# Pending            20227
# Closed             19616
# On_Hold             9804
# Suspected_Fraud     4062
# Canceled            3692
# Payment_Review      1893
# Name: count, dtype: int64

# %%
df1['Shipping Mode'].value_counts()
# Out:
# Shipping Mode
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: count, dtype: int64

# %%
df1['Market'].value_counts()
# Out:
# Market
# LATAM           51594
# Europe          50252
# Pacific Asia    41260
# USCA            25799
# Africa          11614
# Name: count, dtype: int64

# %%
df1['Market']=df1['Market'].str.strip().str.lower().str.title()

# %%
df1['Market'].value_counts()
# Out:
# Market
# Latam           51594
# Europe          50252
# Pacific Asia    41260
# Usca            25799
# Africa          11614
# Name: count, dtype: int64

# %%
df1['Order Status']=df1['Order Status'].replace({'Canceled':'Cancelled','Complete':'Completed'})

# %%
df1['Order Status'].value_counts()
# Out:
# Order Status
# Completed          59491
# Pending_Payment    39832
# Processing         21902
# Pending            20227
# Closed             19616
# On_Hold             9804
# Suspected_Fraud     4062
# Cancelled           3692
# Payment_Review      1893
# Name: count, dtype: int64

# %%
df1['Delivery Status']=df1['Delivery Status'].replace({'Shipping Canceled':'Shipping Cancelled'})

# %%
df1['Delivery Status'].value_counts()
# Out:
# Delivery Status
# Late Delivery         98977
# Advance Shipping      41592
# Shipping On Time      32196
# Shipping Cancelled     7754
# Name: count, dtype: int64

# %%
df1['Market']=df1['Market'].replace({'Latam':'Latin America','Usca':'Usa'})

# %%
df1['Market'].value_counts()
# Out:
# Market
# Latin America    51594
# Europe           50252
# Pacific Asia     41260
# Usa              25799
# Africa           11614
# Name: count, dtype: int64

# %%
df['Type'].value_counts(dropna=False)
# Out:
# Type
# DEBIT       69295
# TRANSFER    49883
# PAYMENT     41725
# CASH        19616
# Name: count, dtype: int64

# %%
df1['Type']=df1['Type'].str.strip().str.lower().str.title()

# %% [markdown]
# Standardized categorical values by replacing inconsistent category names (e.g., Cancelled -- Canceled and Complete -- Completed) to ensure consistency in analysis and reporting.

# %% [markdown]
# Checking for Impossible Values

# %%
(df1['Sales'] < 0).sum()
# Out:
# np.int64(0)

# %%
(df1['Order Item Quantity'] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df1['Product Price'] < 0).sum()
# Out:
# np.int64(0)

# %%
(df1['Days for shipping (real)'] < 0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# We can see there are no values which are beyond.The values are correct based on the data.

# %%
df1.rename(columns={'order date (DateOrders)':'Order_Date','shipping date (DateOrders)':'Shipping_Date'},inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Id                    180519 non-null  int64
# ...

# %%
df1.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Lastly checking again before saving the file for EDA.

# %%
df1.to_csv('Supply_Chain.csv',index=False)

# %%
files.download('Supply_Chain.csv')
